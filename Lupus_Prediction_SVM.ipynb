# %%
# !pip install scikit-learn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
data = pd.read_csv("data_lupus.csv")
data.head()
# Out:
#    Age  Gender  Sickness time duration  Esbach  MBL Level  ESR     C3   C4  \
# 0   18       1                    58.9       0          0    2    7.3    5
# 1   22       0                    57.2      10       9865   79  194.0  100
# 2   33       0                    64.6       2        456   17  132.0   19
# 3   45       0                    63.9       3        378   18  155.0   78
# 4   56       0                    60.5       6       4567   45   10.9   67
#
#     CRP  ANA  ANTIdsDNA  SLE-DAI  Lupus
# 0   3.0    0          0        0      0
# 1  52.0    1          1       44      1
# 2   4.5    0          0        2      0
# 3  39.0    0          0        4      0
# 4  45.0    0          0        7      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     69 non-null     int64
#  1   Gender                  69 non-null     int64
#  2   Sickness time duration  69 non-null     float64
#  3   Esbach                  69 non-null     int64
#  4   MBL Level               69 non-null     int64
#  5   ESR                     69 non-null     int64
#  6   C3                      69 non-null     float64
#  7   C4                      69 non-null     int64
#  8   CRP                     69 non-null     float64
#  9   ANA                     69 non-null     int64
#  10  ANTIdsDNA               69 non-null     int64
#  11  SLE-DAI                 69 non-null     int64
#  12  Lupus                   69 non-null     int64
# dtypes: float64(3), int64(10)
# memory usage: 7.1 KB

# %%
X= data.drop('Lupus', axis=1)
Y= data['Lupus']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
model = SVC(kernel='linear')  # You can also use 'rbf', 'poly', or 'sigmoid'

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
Predictions = model.predict(X_test)
print(Predictions)
# Out:
# [1 1 0 1 0 1 1 0 1 1 0 1 1 0]

# %%
accuracy = accuracy_score(Y_test, Predictions)

# %%
print(accuracy)
# Out:
# 0.9285714285714286

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (55, 12)
# (14, 12)
# (55,)
# (14,)

# %%
X_test=[54,1,0,122,286,0,0,116,1,3.2,1,2]
Predictions = model.predict([X_test])
print(Predictions)
# Out:
# [0]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
data.head()
# Out:
#    Age  Gender  Sickness time duration  Esbach  MBL Level  ESR     C3   C4  \
# 0   18       1                    58.9       0          0    2    7.3    5
# 1   22       0                    57.2      10       9865   79  194.0  100
# 2   33       0                    64.6       2        456   17  132.0   19
# 3   45       0                    63.9       3        378   18  155.0   78
# 4   56       0                    60.5       6       4567   45   10.9   67
#
#     CRP  ANA  ANTIdsDNA  SLE-DAI  Lupus
# 0   3.0    0          0        0      0
# 1  52.0    1          1       44      1
# 2   4.5    0          0        2      0
# 3  39.0    0          0        4      0
# 4  45.0    0          0        7      0

# %%
Age=int(input("Enter Age: "))
Gender=int(input("Enter Gender: "))
Sicknesstd=int(input("Enter Sickness Time Duration: "))
Esbach=int(input("Enter Esbach: "))
MBL_level=int(input("Enter MBL Level: "))
ESR=int(input("Enter ESR: "))
C3=int(input("Enter C3: "))
C4=int(input("Enter C4: "))
CRP=int(input("Enter CRP: "))
ANA=float(input("Enter ANA: "))
ANTIdsDNA=int(input("Enter ANTIdsDNA: "))
SLE_DAI=int(input("Enter SLE-DAI: "))
# Out:
# Enter Age:  81
# Enter Gender:  1
# Enter Sickness Time Duration:  32
# Enter Esbach:  4
# Enter MBL Level:  34
# Enter ESR:  32
# Enter C3:  8
# Enter C4:  4
# Enter CRP:  7
# Enter ANA:  32
# Enter ANTIdsDNA:  76
# Enter SLE-DAI:  89

# %%
list=[Age, Gender, Sicknesstd, Esbach, MBL_level, ESR, C3, C4, CRP, ANA, ANTIdsDNA, SLE_DAI]
print(list)
Predictions = model.predict([X_test])
print(Predictions)
# Out:
# [81, 1, 32, 4, 34, 32, 8, 4, 7, 32.0, 76, 89]
# [0]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
if(Predictions[0]==0):
    print("No Lupus Disease")
else:
    print("Lupus Disease")
# Out:
# No Lupus Disease
